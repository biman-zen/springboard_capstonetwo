# %% [markdown]
# # Capstone II: Craiglist Used Car Dataset

# %% [markdown]
# #### Data Wrangling

# %% [markdown]
# Biman Mondal
# Feb. 19, 2025

# %%
#!pip install pandas
#!pip install missingno

# %%
# Import numpy package
import numpy as np
# Import pandas package
import pandas as pd
# Import matplotlib package
import matplotlib.pyplot as plt
# Import the seaborn package
import seaborn as sns
# Import ydata-profiling package
from ydata_profiling import ProfileReport
# Import missingno package
import missingno as msno
# Import datetime
import datetime as dt

# %%
# Dataset .csv file downloaded from Kaggle: 
# https://www.kaggle.com/datasets/austinreese/craigslist-carstrucks-data
# Import data from local .csv file
#chunk_size = 1000 # 
vehicle_raw = pd.read_csv('./data/vehicles.csv')

# %% [markdown]
# # View raw data

# %%
vehicle_raw.head().T
# Out:
#                                                               0  \
# id                                                   7222695916
# url           https://prescott.craigslist.org/cto/d/prescott...
# region                                                 prescott
# region_url                      https://prescott.craigslist.org
# price                                                      6000
# year                                                        NaN
# manufacturer                                                NaN
# model                                                       NaN
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        NaN
# odometer                                                    NaN
# title_status                                                NaN
# transmission                                                NaN
# VIN                                                         NaN
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# image_url                                                   NaN
# description                                                 NaN
# county                                                      NaN
# state                                                        az
# lat                                                         NaN
# long                                                        NaN
# posting_date                                                NaN
#
#                                                               1  \
# id                                                   7218891961
# url           https://fayar.craigslist.org/ctd/d/bentonville...
# region                                             fayetteville
# region_url                         https://fayar.craigslist.org
# price                                                     11900
# year                                                        NaN
# manufacturer                                                NaN
# model                                                       NaN
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        NaN
# odometer                                                    NaN
# title_status                                                NaN
# transmission                                                NaN
# VIN                                                         NaN
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# image_url                                                   NaN
# description                                                 NaN
# county                                                      NaN
# state                                                        ar
# lat                                                         NaN
# long                                                        NaN
# posting_date                                                NaN
#
#                                                               2  \
# id                                                   7221797935
# url           https://keys.craigslist.org/cto/d/summerland-k...
# region                                             florida keys
# region_url                          https://keys.craigslist.org
# price                                                     21000
# year                                                        NaN
# manufacturer                                                NaN
# model                                                       NaN
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        NaN
# odometer                                                    NaN
# title_status                                                NaN
# transmission                                                NaN
# VIN                                                         NaN
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# image_url                                                   NaN
# description                                                 NaN
# county                                                      NaN
# state                                                        fl
# lat                                                         NaN
# long                                                        NaN
# posting_date                                                NaN
#
#                                                               3  \
# id                                                   7222270760
# url           https://worcester.craigslist.org/cto/d/west-br...
# region                                   worcester / central MA
# region_url                     https://worcester.craigslist.org
# price                                                      1500
# year                                                        NaN
# manufacturer                                                NaN
# model                                                       NaN
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        NaN
# odometer                                                    NaN
# title_status                                                NaN
# transmission                                                NaN
# VIN                                                         NaN
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# image_url                                                   NaN
# description                                                 NaN
# county                                                      NaN
# state                                                        ma
# lat                                                         NaN
# long                                                        NaN
# posting_date                                                NaN
#
#                                                               4
# id                                                   7210384030
# url           https://greensboro.craigslist.org/cto/d/trinit...
# region                                               greensboro
# region_url                    https://greensboro.craigslist.org
# price                                                      4900
# year                                                        NaN
# manufacturer                                                NaN
# model                                                       NaN
# condition                                                   NaN
# cylinders                                                   NaN
# fuel                                                        NaN
# odometer                                                    NaN
# title_status                                                NaN
# transmission                                                NaN
# VIN                                                         NaN
# drive                                                       NaN
# size                                                        NaN
# type                                                        NaN
# paint_color                                                 NaN
# image_url                                                   NaN
# description                                                 NaN
# county                                                      NaN
# state                                                        nc
# lat                                                         NaN
# long                                                        NaN
# posting_date                                                NaN

# %%
# Get the data information
vehicle_raw.info()
raw_rows_cols = vehicle_raw.shape
print('\n\n',raw_rows_cols)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426880 entries, 0 to 426879
# Data columns (total 26 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            426880 non-null  int64
#  1   url           426880 non-null  object
#  2   region        426880 non-null  object
#  3   region_url    426880 non-null  object
#  4   price         426880 non-null  int64
#  5   year          425675 non-null  float64
#  6   manufacturer  409234 non-null  object
#  7   model         421603 non-null  object
#  8   condition     252776 non-null  object
#  9   cylinders     249202 non-null  object
#  10  fuel          423867 non-null  object
#  11  odometer      422480 non-null  float64
#  12  title_status  418638 non-null  object
#  13  transmission  424324 non-null  object
#  14  VIN           265838 non-null  object
#  15  drive         296313 non-null  object
#  16  size          120519 non-null  object
#  17  type          334022 non-null  object
#  18  paint_color   296677 non-null  object
#  19  image_url     426812 non-null  object
#  20  description   426810 non-null  object
#  21  county        0 non-null       float64
#  22  state         426880 non-null  object
#  23  lat           420331 non-null  float64
#  24  long          420331 non-null  float64
#  25  posting_date  426812 non-null  object
# dtypes: float64(5), int64(2), object(19)
# memory usage: 84.7+ MB
#
#
#  (426880, 26)

# %% [markdown]
# Viewing the dataset shows that it has 26 columns and 426,880 rows.
# The posting date needs to be converted to date time object

# %% [markdown]
# ## Convert data types

# %%
# Convert data to datetime
vehicle_raw['posting_date'] = vehicle_raw['posting_date'].apply(pd.to_datetime)

# %%
# Convert year of make/model to year
#vehicle_raw['year'] = vehicle_raw['year'].astype('int')

# %%
vehicle_raw['county'] = vehicle_raw['county'].astype('object')

# %% [markdown]
# ### Create a dataframe of missing data for select columns

# %%
# Create a profile report of the data 
# Profile = ProfileReport(vehicle, title='Profiling Report')
# Wait until the dataset is clean in order to profile the data
# Profile.to_file("data_profile.html")

#print(vehicle_raw[['price','year','manufacturer','model','description']].isnull().sum())
#print(100*vehicle_raw[['price','year','manufacturer','model','description']].isnull().sum()/raw_rows_cols[0])
#print(vehicle_raw[['description']].isna().sum())

missing_data = {
                'no_missing_values': vehicle_raw[['price','year','manufacturer','model','description']].isnull().sum(),
                'percent_missing': 100*vehicle_raw[['price','year','manufacturer','model','description']].isnull().sum()/raw_rows_cols[0]
}
missing_data = pd.DataFrame(missing_data)
# missing_data.rename(columns = {0: "missing_values"},inplace=True)
# missing_data['percent_missing'] = 100*vehicle_raw[['price','year','manufacturer','model','description']].isnull().sum()/raw_rows_cols[0]
missing_data.head()
# Out:
#               no_missing_values  percent_missing
# price                         0         0.000000
# year                       1137         0.266351
# manufacturer              17578         4.117785
# model                      5209         1.220249
# description                   0         0.000000

# %% [markdown]
# About 1,205 entries or 0.28% are are missing from the 'year' column.
# About 17,646 or 4.13% entries are missing from the 'manufacturer' column.
# About 5,277 or 1.23% of entries are missing from the 'model' column.
# About 70 entries don't include a description.
# Delete any entry where the description, model and manufacturer is missing.

# %%
# vehicle_raw["posting_date"].describe()
vehicle_raw.head().T
# Out:
#                                                               0  \
# id                                                   7316814884
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     33590
# year                                                     1970.0
# manufacturer                                                gmc
# model                                  sierra 1500 crew cab slt
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                57923.0
# title_status                                              clean
# transmission                                              other
# VIN                                           3GTP1VEC4EG551563
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                               white
# image_url     https://images.craigslist.org/00R0R_lwWjXSEWNa...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 12:31:18-05:00
#
#                                                               1  \
# id                                                   7316814758
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     22590
# year                                                     1970.0
# manufacturer                                          chevrolet
# model                                            silverado 1500
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                71229.0
# title_status                                              clean
# transmission                                              other
# VIN                                           1GCSCSE06AZ123805
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                                blue
# image_url     https://images.craigslist.org/00R0R_lwWjXSEWNa...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 12:31:08-05:00
#
#                                                               2  \
# id                                                   7316814989
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     39590
# year                                                     1970.0
# manufacturer                                          chevrolet
# model                                       silverado 1500 crew
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                19160.0
# title_status                                              clean
# transmission                                              other
# VIN                                           3GCPWCED5LG130317
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                                 red
# image_url     https://images.craigslist.org/01212_jjirIWa0y0...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 12:31:25-05:00
#
#                                                               3  \
# id                                                   7316743432
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     30990
# year                                                     1970.0
# manufacturer                                             toyota
# model                                      tundra double cab sr
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                41124.0
# title_status                                              clean
# transmission                                              other
# VIN                                           5TFRM5F17HX120972
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                                 red
# image_url     https://images.craigslist.org/00x0x_1y9kIOzGCF...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 10:41:31-05:00
#
#                                                               4
# id                                                   7316356412
# url           https://auburn.craigslist.org/cto/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     15000
# year                                                     1970.0
# manufacturer                                               ford
# model                                                 f-150 xlt
# condition                                             excellent
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                               128000.0
# title_status                                              clean
# transmission                                          automatic
# VIN                                                         NaN
# drive                                                       rwd
# size                                                  full-size
# type                                                      truck
# paint_color                                               black
# image_url     https://images.craigslist.org/00404_l4loxHvdQe...
# description   2013 F-150 XLT V6 4 Door. Good condition. Leve...
# county                                                      NaN
# state                                                        al
# lat                                                      32.592
# long                                                   -85.5189
# posting_date                          2021-05-03 14:02:03-05:00

# %% [markdown]
# ### Convert Specific Features to Categories

# %%
# Convert the posting_date column to datetime
# Change fuel tye, manufacturer, model, condition, cylinders
# Find data that doesn't have any description, year, manufacturer, and model and remove the data from the set

# %%
vehicle_raw["condition"].unique()
# Out:
# array([nan, 'good', 'excellent', 'fair', 'like new', 'new', 'salvage'],
#       dtype=object)

# %%
vehicle_raw["cylinders"].unique()
# Out:
# array([nan, '8 cylinders', '6 cylinders', '4 cylinders', '5 cylinders',
#        'other', '3 cylinders', '10 cylinders', '12 cylinders'],
#       dtype=object)

# %%
vehicle_raw["fuel"].unique()
# Out:
# array([nan, 'gas', 'other', 'diesel', 'hybrid', 'electric'], dtype=object)

# %%
vehicle_raw["type"].unique()
# Out:
# array([nan, 'pickup', 'truck', 'other', 'coupe', 'SUV', 'hatchback',
#        'mini-van', 'sedan', 'offroad', 'bus', 'van', 'convertible',
#        'wagon'], dtype=object)

# %%
vehicle_raw["title_status"].unique()
# Out:
# array([nan, 'clean', 'rebuilt', 'lien', 'salvage', 'missing',
#        'parts only'], dtype=object)

# %%
# Convert the following columns to category
vehicle_raw[["condition","cylinders", "fuel", "type", "title_status"]] = vehicle_raw[["condition","cylinders", "fuel", "type", "title_status"]].astype('category')

# %% [markdown]
# ### Drop Missing Data

# %%
# Drop all data associated with an empty description
# ~ 70 rows
#condition = vehicle_raw['description'].isnull() & vehicle_raw['manufacturer'].isnull()
#condition = vehicle_raw['description'].isnull()
#vehicle_raw[condition].head()
#vehicle_raw.drop(vehicle_raw[condition].index,inplace=True)
#missing_data.head()

# %%
import re

# %%
missing_VIN['description'].iloc[1]
# Out:
# "Selling my 2019 Toyota Tacoma TRD Off Road Double Cab 5ft Bed in Cement Grey  This beautiful truck is in great condition and has been taken care of for the past three years and has had only one owner (myself). It only has 43,000 miles on it and has hundreds of thousands of miles ahead of itself and is a great option for anyone interested in Tacomas or just a sturdy reliable vehicle. I'm selling this as I am investing more of my money into other hobbies and I am also looking to get into an old 4Runner, Landcruiser or Sequoia.  The truck is stock and has had regular maintenance conducted. Weather Tech Mats are installed and included and have made a huge difference in preserving the vehicle. The title is Clean and the truck has not been in any Car Accidents. It does has signs of use like small scratches and dents however they are small and the Cement Gray body color helps reduce their visibility.  Looking for $35,000 or a Trade w/Cash for a late 1990s or early 2000s 4Runner, Landcruiser or Sequoia.   If interested please email me and we can arrange a test drive and/or inspection. Looking for Check in which we would go to your bank to ensure it clears. No Payment Plans will be accepted."

# %%
# Missing date

#condition = vehicle_raw['VIN'].isnull()
missing_VIN = vehicle_raw[vehicle_raw['VIN'].isnull()]
#missing_VIN['VIN'].head()
match = re.search(r"VIN:", missing_VIN['description'].iloc[1])
print(match)
#print(missing_VIN.shape[0]/vehicle_raw.shape[0])
# Out:
# None

# %%
# Reset index
#vehicle_raw.reset_index(drop=True,inplace=True) 
#vehicle_raw = vehicle_raw.drop(['level_0', 'index'],axis=1)
#vehicle_raw.head()
vehicle_raw.head().T
# Out:
#                                                               0  \
# id                                                   7316814884
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     33590
# year                                                     1970.0
# manufacturer                                                gmc
# model                                  sierra 1500 crew cab slt
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                57923.0
# title_status                                              clean
# transmission                                              other
# VIN                                           3GTP1VEC4EG551563
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                               white
# image_url     https://images.craigslist.org/00R0R_lwWjXSEWNa...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 12:31:18-05:00
#
#                                                               1  \
# id                                                   7316814758
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     22590
# year                                                     1970.0
# manufacturer                                          chevrolet
# model                                            silverado 1500
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                71229.0
# title_status                                              clean
# transmission                                              other
# VIN                                           1GCSCSE06AZ123805
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                                blue
# image_url     https://images.craigslist.org/00R0R_lwWjXSEWNa...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 12:31:08-05:00
#
#                                                               2  \
# id                                                   7316814989
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     39590
# year                                                     1970.0
# manufacturer                                          chevrolet
# model                                       silverado 1500 crew
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                19160.0
# title_status                                              clean
# transmission                                              other
# VIN                                           3GCPWCED5LG130317
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                                 red
# image_url     https://images.craigslist.org/01212_jjirIWa0y0...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 12:31:25-05:00
#
#                                                               3  \
# id                                                   7316743432
# url           https://auburn.craigslist.org/ctd/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     30990
# year                                                     1970.0
# manufacturer                                             toyota
# model                                      tundra double cab sr
# condition                                                  good
# cylinders                                           8 cylinders
# fuel                                                        gas
# odometer                                                41124.0
# title_status                                              clean
# transmission                                              other
# VIN                                           5TFRM5F17HX120972
# drive                                                       NaN
# size                                                        NaN
# type                                                     pickup
# paint_color                                                 red
# image_url     https://images.craigslist.org/00x0x_1y9kIOzGCF...
# description   Carvana is the safer way to buy a car During t...
# county                                                      NaN
# state                                                        al
# lat                                                       32.59
# long                                                     -85.48
# posting_date                          2021-05-04 10:41:31-05:00
#
#                                                               4
# id                                                   7316356412
# url           https://auburn.craigslist.org/cto/d/auburn-uni...
# region                                                   auburn
# region_url                        https://auburn.craigslist.org
# price                                                     15000
# year                                                     1970.0
# manufacturer                                               ford
# model                                                 f-150 xlt
# condition                                             excellent
# cylinders                                           6 cylinders
# fuel                                                        gas
# odometer                                               128000.0
# title_status                                              clean
# transmission                                          automatic
# VIN                                                         NaN
# drive                                                       rwd
# size                                                  full-size
# type                                                      truck
# paint_color                                               black
# image_url     https://images.craigslist.org/00404_l4loxHvdQe...
# description   2013 F-150 XLT V6 4 Door. Good condition. Leve...
# county                                                      NaN
# state                                                        al
# lat                                                      32.592
# long                                                   -85.5189
# posting_date                          2021-05-03 14:02:03-05:00

# %% [markdown]
# ## Plot missing data in data frame

# %%
msno.matrix(vehicle_raw)
plt.show()

# %%
#vehicle_raw['region_url'].iloc[500]
#print(vehicle_raw['posting_date'].iloc[500])
myfilter = vehicle_raw['year'].isnull()
vehicle_raw[myfilter].count()
# Out:
# id              1137
# url             1137
# region          1137
# region_url      1137
# price           1137
# year               0
# manufacturer       6
# model           1137
# condition         10
# cylinders       1118
# fuel             937
# odometer        1136
# title_status     893
# transmission    1137
# VIN             1137
# drive            905
# size               0
# type            1014
# paint_color     1050
# image_url       1137
# description     1137
# county             0
# state           1137
# lat             1137
# long            1137
# posting_date    1137
# dtype: int64

# %% [markdown]
# ## Missing Lat/Lon

# %%
# Find all the empty fields in latitude and longitude 
missing_lat = vehicle_raw['lat'].isna()
# Find the associated region and state and create a dataframe
regions_state_missing_lat = vehicle_raw.loc[missing_lat,['region','state']]
# Print statement
print(f'There are {regions_state_missing_lat.shape[0]} missing values in the lat/lon columns.')

#state_missing_lat = vehicle_raw.loc[missing_lat,'state']
#print(regions_state_missing_lat[200:220])
#print(state_missing_lat[0:10])
#print(vehicle_raw.loc[vehicle_raw['lat'].notna(),'region'].count())
# Out:
# There are 6481 missing values in the lat/lon columns.

# %% [markdown]
# ## Read .json file of county-city-state-zip-lat-lon dataset

# %% [markdown]
# The county field is completely empty in the dataset. Although not fully necessary, it can be found through the region and state.
# Viewing the regions of missing lat/long pairs shows that some regions have a "/" and some have "-". Some regions are also the county of the state.
# So the first task is to create a function that splits the region, determines if the region is a county, and then if it is not a county send a request to the geopy api to determine the county name.

# %%
# Create a dataframe of zip, lat, lon, city, state, county 
# Data from github project: https://github.com/millbj92/US-Zip-Codes-JSON
# Read .json file 
us_df = pd.read_json('./US-Zip-Codes-JSON-master/USCities.json')

# %%
print(us_df.head())
print(us_df.info())
# Out:
#    zip_code   latitude  longitude        city state     county
# 0       501  40.922326 -72.637078  Holtsville    NY    Suffolk
# 1       544  40.922326 -72.637078  Holtsville    NY    Suffolk
# 2       601  18.165273 -66.722583    Adjuntas    PR   Adjuntas
# 3       602  18.393103 -67.180953      Aguada    PR     Aguada
# 4       603  18.455913  -67.14578   Aguadilla    PR  Aguadilla
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42741 entries, 0 to 42740
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   zip_code   42741 non-null  int64
#  1   latitude   42741 non-null  object
#  2   longitude  42741 non-null  object
#  3   city       42741 non-null  object
#  4   state      42741 non-null  object
#  5   county     42741 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 2.0+ MB
# None

# %%
# Convert all city, state, county to lower case
us_df[["city","state","county"]] = us_df[["city","state","county"]].apply(lambda row: row.str.lower())
us_df.head()
# Out:
#    zip_code   latitude  longitude        city state     county
# 0       501  40.922326 -72.637078  holtsville    ny    suffolk
# 1       544  40.922326 -72.637078  holtsville    ny    suffolk
# 2       601  18.165273 -66.722583    adjuntas    pr   adjuntas
# 3       602  18.393103 -67.180953      aguada    pr     aguada
# 4       603  18.455913  -67.14578   aguadilla    pr  aguadilla

# %% [markdown]
# ### Subset the original vehicle dataset to unique region/state pairs

# %%
# Reduce the craiglist dataset to unique pairs of region-state
region_state = vehicle_raw[['region','state']]
print(f"Original dataset has: {region_state.shape[0]} rows")
unique_region_state = region_state.drop_duplicates()
print(f"Reduced dataframe has: {unique_region_state.shape[0]} rows")
unique_region_state.head()
# Out:
# Original dataset has: 426810 rows
# Reduced dataframe has: 426 rows
#                         region state
# 0                       auburn    al
# 142                 birmingham    al
# 1789                    dothan    al
# 2114  florence / muscle shoals    al
# 2279          gadsden-anniston    al

# %% [markdown]
# Reducing the dataset to unique region will decrease the number of queries between dataframes.

# %%
# Find all the regions within a given state
unique_region_state.loc[unique_region_state['state']=="oh","region"]
# Out:
# 286221            akron / canton
# 288432                 ashtabula
# 288702                    athens
# 288822               chillicothe
# 289079                cincinnati
# 292049                 cleveland
# 294996                  columbus
# 297965      dayton / springfield
# 299752        huntington-ashland
# 299754            lima / findlay
# 300239                 mansfield
# 300598        northern panhandle
# 300866      parkersburg-marietta
# 301130                  sandusky
# 301374                    toledo
# 302780             tuscarawas co
# 302934                youngstown
# 303598    zanesville / cambridge
# Name: region, dtype: object

# %% [markdown]
# Sometimes the regions in the Craigslist dataframe include two city pairs which are in the same state. The city pairs are separated by a "/" or a "-". For the Ohio example, "huntington-ashland" include a three state region (KY-OH-WV). Huntington and Ashland both are both outside Ohio. So this needs to be considered in order to find correct county.
#
# Certain regions in the Craigslist dataframe are the county already. County is sometimes spelled out "county" or abbreviated as "co". For certain cities on the border of a state, the city and the state are included. (st. louis, MO is included in IL).

# %%
my_condition = (us_df['city'].str.contains("chicago")) & (us_df['state']=="il")
unique_vals = us_df.loc[my_condition,"county"].unique()
print(unique_vals)
len(us_df.loc[my_condition,"county"].unique())
# Out:
# ['lake' 'du page' 'cook']
# 3

# %%
foo = pd.Series(us_df.loc[my_condition,"county"])
print(foo.describe())
print(foo.describe().top)
# Out:
# count       92
# unique       3
# top       cook
# freq        88
# Name: county, dtype: object
# cook

# %%
county = lookup_func(us_df,"detroit","mi",1)
unique_region_state.head()
# Out:
#                         region state                    split_region  \
# 0                       auburn    al                        [auburn]
# 142                 birmingham    al                    [birmingham]
# 1789                    dothan    al                        [dothan]
# 2114  florence / muscle shoals    al  [florence, , , muscle, shoals]
# 2279          gadsden-anniston    al              [gadsden-anniston]
#
#           county
# 0            lee
# 142    jefferson
# 1789     houston
# 2114  lauderdale
# 2279         NaN

# %%
# Split the region into a list of multiple values
unique_region_state.loc[:,"split_region"] = unique_region_state["region"].str.split(r"[/|-]",expand=False)
unique_region_state.head()
# Out:
#                         region state                 split_region      county
# 0                       auburn    al                     [auburn]         lee
# 142                 birmingham    al                 [birmingham]   jefferson
# 1789                    dothan    al                     [dothan]     houston
# 2114  florence / muscle shoals    al  [florence ,  muscle shoals]  lauderdale
# 2279          gadsden-anniston    al          [gadsden, anniston]         NaN

# %%
def lookup_func(df,region,state,item):
"""
Create a function that looks up state-region dataframe
"""
    # Choose what to output from the dataframe
    if item == 1:
        find_val = "county"
    elif item == 2:
        find_val = "latitude"
    elif item == 3:
        find_val = "longitude"
    elif item == 4:
        find_val = "zip code"
    else: 
        raise ValueError("Item value must be 1-4")
    
    # There is only a single item in the split_region
    my_condition = (df['city'].str.match(region)) & (df['state']==state)
    # 
    county_list = pd.Series(df.loc[my_condition,find_val])
    # The .describe().top method returns the most frequent county in that region
    return county_list.describe().top

# %% [markdown]
# ### Apply a lookup function to find the county

# %%
# Assign the county value using applying lookup function to each row
unique_region_state.loc[:,"county"] = unique_region_state.apply(lambda row: lookup_func(us_df,str.strip(row.split_region[0]),row.state,1),axis=1)

# %%
#unique_region_state.drop("county",axis=1,inplace=True)
unique_region_state.tail(10)
# Out:
#                 region state      split_region     county
# 416920       green bay    wi      [green, bay]      brown
# 417953      janesville    wi      [janesville]       rock
# 418296  kenosha-racine    wi  [kenosha-racine]        NaN
# 419053       la crosse    wi      [la, crosse]  la crosse
# 419573         madison    wi         [madison]       dane
# 421960       milwaukee    wi       [milwaukee]  milwaukee
# 424931     northern WI    wi    [northern, WI]        NaN
# 425193       sheboygan    wi       [sheboygan]  sheboygan
# 425474          wausau    wi          [wausau]   marathon
# 426200         wyoming    wy         [wyoming]        NaN

# %%
# Sum the null values in county column
print(f'There are still: {unique_region_state["county"].isna().sum()} counties that are NaN.')
# Out:
# There are still: 94 counties that are NaN

# %%
# Find region that says "county"
# Replace that row in the county column with the region
region_includes_county = unique_region_state['region'].str.contains('county')
unique_region_state.loc[region_includes_county,"county"] = unique_region_state.loc[region_includes_county,"region"]
#unique_region_state.tail()

# %%
# Sum the null values in county column
region_includes_county = unique_region_state['region'].str.endswith('co')
unique_region_state[region_includes_county]
#print(f'There are still: {unique_region_state["county"].isna().sum()} counties that are NaN')
# Out:
#                region state      split_region         county
# 23671           chico    ca           [chico]          chico
# 142974    la salle co    il   [la, salle, co]    la salle co
# 302780  tuscarawas co    oh  [tuscarawas, co]  tuscarawas co
# 384238           waco    tx            [waco]           waco

# %%
# Sum the null values in county column
print(f'There are still: {unique_region_state["county"].isna().sum()} counties that are NaN.')
# Out:
# There are still: 92 counties that are NaN

# %%
filter_null_vals = unique_region_state["county"].isna()
unique_region_state[filter_null_vals].head(20)
# Out:
#                        region state                  split_region county
# 2279         gadsden-anniston    al            [gadsden-anniston]    NaN
# 8345         southeast alaska    ak           [southeast, alaska]    NaN
# 28905        hanford-corcoran    ca            [hanford-corcoran]    NaN
# 29750           inland empire    ca              [inland, empire]    NaN
# 48407            reno / tahoe    ca             [reno, , , tahoe]    NaN
# 60453             SF bay area    ca               [SF, bay, area]    NaN
# 69085          visalia-tulare    ca              [visalia-tulare]    NaN
# 70006             yuba-sutter    ca                 [yuba-sutter]    NaN
# 78312              eastern CO    co                 [eastern, CO]    NaN
# 80733            high rockies    co               [high, rockies]    NaN
# 81648           western slope    co              [western, slope]    NaN
# 82836              eastern CT    ct                 [eastern, CT]    NaN
# 87626            northwest CT    ct               [northwest, CT]    NaN
# 88023          washington, DC    dc             [washington,, DC]    NaN
# 93575            florida keys    fl               [florida, keys]    NaN
# 93777   ft myers / SW florida    fl  [ft, myers, , , SW, florida]    NaN
# 97657       heartland florida    fl          [heartland, florida]    NaN
# 103894      okaloosa / walton    fl        [okaloosa, , , walton]    NaN
# 107991     sarasota-bradenton    fl          [sarasota-bradenton]    NaN
# 113888            space coast    fl                [space, coast]    NaN

# %% [markdown]
# ### Apply a lookup function to find the latitude

# %%
my_filter = vehicle_raw['long'].isnull()
#
regions_without_latlon = vehicle_raw.loc[my_filter,['region','state','county','lat','long']].drop_duplicates()
regions_without_latlon.head()
# Out:
#                     region state county  lat  long
# 231             birmingham    al    NaN  NaN   NaN
# 2021                dothan    al    NaN  NaN   NaN
# 2290      gadsden-anniston    al    NaN  NaN   NaN
# 2554  huntsville / decatur    al    NaN  NaN   NaN
# 3777                mobile    al    NaN  NaN   NaN
